# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MansiNegi281/CapstoneFlyrankAI/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# My Lane - Refresh/Content Opportunity Scoring
#
# I picked the Refresh / Content Opportunity Scoring lane because it is, about finding the webpages that need to be looked at first for new content. This project does not just use rules that people made it uses things that we can see like what people search for and how they interact with the website to figure out which pages should be reviewed first. The goal of the Refresh / Content Opportunity Scoring lane is to help the people who make the content use their time in the way possible so they work on the Refresh / Content Opportunity Scoring lane pages that will make the biggest difference.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Research Question - We need to figure out which webpages should be updated first. We will look at how they do, in search results how many people interact with them and how old the content is.
#
# Decision - We have to decide which pages the content team should look at first.
#
# Action - A person who edits content will look at the important pages and make them better based on what we suggest.
#
# Cost of a Wrong Suggestion - If we suggest the pages the team will waste time on pages that are fine and they will not fix the pages that are actually doing poorly. This makes the whole process of checking content less useful.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("/content/content_refresh_anonymized.csv")
df.head()

print(df.shape)
print(df.columns.tolist())
print(df["trend_direction"].value_counts())
print("Summary Statistics:")
print(df[["impressions_90d", "content_age_days", "sessions_90d"]].describe())
# Out:
# (30000, 44)
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# Summary Statistics:
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can say about this project:
#
# 1.This project looks at patterns in things like how many people see our content how times they visit our site, how old the content is, how often they click on it and where it shows up in search results.
#
# 2.The analysis is like a guide that helps us figure out which pages might need some work based on what we can see.
#
# 3.The results help us decide which pages to look at first to make them better or more appealing, to people.
#
# What I cannot say about this project:
#
# 1.I don't know if updating a page will make it more popular or show up higher in search results.
#
# 2.I am not saying that this project knows how Google decides what shows up first in search results or what makes a page show up higher.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
